# %%
# Import the dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size= 2000)

lngs = np.random.uniform(low = -180.000, high=180.000, size =2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.


from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#print(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
# for i, city in enumerate(cities): is orginal code but I stop at 50 so I can go on.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #city_description = city_weather[0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
##weather.description
# Out:
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | tres passos
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | rawson
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | marawi
# Processing Record 14 of Set 1 | eydhafushi
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | itarema
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | linxia
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | makarska
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | sawakin
# Processing Record 28 of Set 1 | vila
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | saint-pierre
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | canchungo
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | grindavik
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | makakilo city
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | touros
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | manokwari
# Processing Record 4 of Set 2 | salamiyah
# Processing Record 5 of Set 2 | saeby
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | iralaya
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | lewistown
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 2 | the valley
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | mitsamiouli
# Processing Record 19 of Set 2 | alyangula
# Processing Record 20 of Set 2 | laguna
# Processing Record 21 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 2 | agirish
# Processing Record 23 of Set 2 | isangel
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | varhaug
# Processing Record 27 of Set 2 | chengde
# Processing Record 28 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 2 | ixtapa
# Processing Record 30 of Set 2 | gat
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | boa vista
# Processing Record 33 of Set 2 | kenai
# Processing Record 34 of Set 2 | burica
# City not found. Skipping...
# Processing Record 35 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | kotka
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | smithers
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | coos bay
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | port moresby
# Processing Record 44 of Set 2 | port-gentil
# Processing Record 45 of Set 2 | rio grande
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | sansai
# City not found. Skipping...
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | samarai
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | praia da vitoria
# Processing Record 4 of Set 3 | margate
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | reefton
# City not found. Skipping...
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | saint-joseph
# Processing Record 11 of Set 3 | alofi
# Processing Record 12 of Set 3 | mongu
# Processing Record 13 of Set 3 | la orilla
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | muros
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | maribo
# Processing Record 18 of Set 3 | yakima
# Processing Record 19 of Set 3 | cibitoke
# Processing Record 20 of Set 3 | nouadhibou
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | tombouctou
# Processing Record 23 of Set 3 | quatre cocos
# Processing Record 24 of Set 3 | kaeo
# Processing Record 25 of Set 3 | rio branco
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | ulladulla
# Processing Record 29 of Set 3 | ponta delgada
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | meulaboh
# Processing Record 32 of Set 3 | domoni
# Processing Record 33 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | saint-francois
# Processing Record 37 of Set 3 | port blair
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | sulya
# Processing Record 41 of Set 3 | qaqortoq
# Processing Record 42 of Set 3 | quartucciu
# Processing Record 43 of Set 3 | maltahohe
# Processing Record 44 of Set 3 | kahuta
# Processing Record 45 of Set 3 | ambon
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | bograd
# Processing Record 48 of Set 3 | maragogi
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | dunedin
# Processing Record 1 of Set 4 | nemuro
# Processing Record 2 of Set 4 | vredendal
# Processing Record 3 of Set 4 | gorontalo
# Processing Record 4 of Set 4 | madimba
# Processing Record 5 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 4 | santa lucia
# Processing Record 10 of Set 4 | khandyga
# Processing Record 11 of Set 4 | tumarbong
# Processing Record 12 of Set 4 | ueda
# Processing Record 13 of Set 4 | chifeng
# Processing Record 14 of Set 4 | rockhampton
# Processing Record 15 of Set 4 | westport
# Processing Record 16 of Set 4 | muhos
# Processing Record 17 of Set 4 | naryan-mar
# Processing Record 18 of Set 4 | male
# Processing Record 19 of Set 4 | morro bay
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | gawler
# Processing Record 22 of Set 4 | sarakhs
# Processing Record 23 of Set 4 | mackay
# Processing Record 24 of Set 4 | adre
# Processing Record 25 of Set 4 | asau
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | rocha
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | hofn
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | bundaberg
# Processing Record 35 of Set 4 | tessalit
# Processing Record 36 of Set 4 | buenaventura
# Processing Record 37 of Set 4 | mae sot
# Processing Record 38 of Set 4 | pauini
# Processing Record 39 of Set 4 | sovetskaya gavan
# Processing Record 40 of Set 4 | iskilip
# Processing Record 41 of Set 4 | aykhal
# Processing Record 42 of Set 4 | sestri levante
# Processing Record 43 of Set 4 | khani
# Processing Record 44 of Set 4 | aksay
# Processing Record 45 of Set 4 | kedrovyy
# Processing Record 46 of Set 4 | changde
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | lentekhi
# Processing Record 49 of Set 4 | sioux lookout
# Processing Record 50 of Set 4 | russell
# Processing Record 1 of Set 5 | nabire
# Processing Record 2 of Set 5 | genhe
# Processing Record 3 of Set 5 | andenes
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | algeciras
# Processing Record 6 of Set 5 | milkovo
# Processing Record 7 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 5 | maneromango
# Processing Record 9 of Set 5 | kapuskasing
# Processing Record 10 of Set 5 | taiyuan
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | crixas
# Processing Record 13 of Set 5 | bardiyah
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | tautira
# Processing Record 16 of Set 5 | zhanaozen
# Processing Record 17 of Set 5 | bacolod
# Processing Record 18 of Set 5 | boyolangu
# Processing Record 19 of Set 5 | clyde river
# Processing Record 20 of Set 5 | ust-tsilma
# Processing Record 21 of Set 5 | abu samrah
# Processing Record 22 of Set 5 | tuma
# Processing Record 23 of Set 5 | tura
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | teya
# Processing Record 26 of Set 5 | cairns
# Processing Record 27 of Set 5 | tarakan
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | astana
# Processing Record 30 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | hay river
# Processing Record 35 of Set 5 | honningsvag
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 5 | lima
# Processing Record 39 of Set 5 | sumbe
# Processing Record 40 of Set 5 | mareeba
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | nowy targ
# Processing Record 43 of Set 5 | pacific grove
# Processing Record 44 of Set 5 | chukhloma
# Processing Record 45 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 5 | georgetown
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 5 | kibaya
# Processing Record 50 of Set 5 | igboho
# Processing Record 1 of Set 6 | thoen
# Processing Record 2 of Set 6 | zhezkazgan
# Processing Record 3 of Set 6 | abashiri
# Processing Record 4 of Set 6 | canete
# Processing Record 5 of Set 6 | tuktoyaktuk
# Processing Record 6 of Set 6 | zihuatanejo
# Processing Record 7 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 6 | newport
# Processing Record 9 of Set 6 | manjeshwar
# Processing Record 10 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | locri
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | shache
# Processing Record 15 of Set 6 | erzin
# Processing Record 16 of Set 6 | anadyr
# Processing Record 17 of Set 6 | palu
# Processing Record 18 of Set 6 | mopti
# Processing Record 19 of Set 6 | bunol
# Processing Record 20 of Set 6 | los chiles
# Processing Record 21 of Set 6 | jalu
# Processing Record 22 of Set 6 | timbiqui
# Processing Record 23 of Set 6 | havelock
# Processing Record 24 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | koshurnikovo
# Processing Record 27 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 6 | jimenez
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | klyavlino
# Processing Record 31 of Set 6 | gwanda
# Processing Record 32 of Set 6 | saint george
# Processing Record 33 of Set 6 | liverpool
# Processing Record 34 of Set 6 | angra
# City not found. Skipping...
# Processing Record 35 of Set 6 | nacogdoches
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | nokaneng
# Processing Record 38 of Set 6 | dwarka
# Processing Record 39 of Set 6 | brigham city
# Processing Record 40 of Set 6 | sao filipe
# Processing Record 41 of Set 6 | talnakh
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | amahai
# Processing Record 44 of Set 6 | nanao
# Processing Record 45 of Set 6 | dmitriyevka
# Processing Record 46 of Set 6 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 47 of Set 6 | san felipe
# Processing Record 48 of Set 6 | huarmey
# Processing Record 49 of Set 6 | jupiter
# Processing Record 50 of Set 6 | coihaique
# Processing Record 1 of Set 7 | wanning
# Processing Record 2 of Set 7 | massena
# Processing Record 3 of Set 7 | norman wells
# Processing Record 4 of Set 7 | paamiut
# Processing Record 5 of Set 7 | winston
# Processing Record 6 of Set 7 | navrongo
# Processing Record 7 of Set 7 | kendari
# Processing Record 8 of Set 7 | ilulissat
# Processing Record 9 of Set 7 | prainha
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | ensley
# Processing Record 14 of Set 7 | karangampel
# Processing Record 15 of Set 7 | kyabram
# Processing Record 16 of Set 7 | bowen
# Processing Record 17 of Set 7 | san juan del cesar
# Processing Record 18 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | waipawa
# Processing Record 20 of Set 7 | flin flon
# Processing Record 21 of Set 7 | yeppoon
# Processing Record 22 of Set 7 | saint anthony
# Processing Record 23 of Set 7 | chicama
# Processing Record 24 of Set 7 | kungurtug
# Processing Record 25 of Set 7 | seredka
# Processing Record 26 of Set 7 | humaita
# Processing Record 27 of Set 7 | bonavista
# Processing Record 28 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | srednekolymsk
# Processing Record 31 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 7 | altus
# Processing Record 33 of Set 7 | teano
# Processing Record 34 of Set 7 | bhandaria
# Processing Record 35 of Set 7 | labuhan
# Processing Record 36 of Set 7 | hisor
# Processing Record 37 of Set 7 | kununurra
# Processing Record 38 of Set 7 | olinda
# Processing Record 39 of Set 7 | naze
# Processing Record 40 of Set 7 | corrente
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | hanumangarh
# Processing Record 44 of Set 7 | hervey bay
# Processing Record 45 of Set 7 | igrim
# Processing Record 46 of Set 7 | bilibino
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | sergeyevka
# Processing Record 49 of Set 7 | nenjiang
# Processing Record 50 of Set 7 | bom jesus da lapa
# Processing Record 1 of Set 8 | verkhnyaya inta
# Processing Record 2 of Set 8 | carupano
# Processing Record 3 of Set 8 | lexington
# Processing Record 4 of Set 8 | lufilufi
# Processing Record 5 of Set 8 | alugan
# Processing Record 6 of Set 8 | egvekinot
# Processing Record 7 of Set 8 | seoul
# Processing Record 8 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 9 of Set 8 | akyab
# Processing Record 10 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 8 | sola
# Processing Record 12 of Set 8 | souillac
# Processing Record 13 of Set 8 | teresina
# Processing Record 14 of Set 8 | mehamn
# Processing Record 15 of Set 8 | la cruz
# Processing Record 16 of Set 8 | murgab
# Processing Record 17 of Set 8 | hovd
# Processing Record 18 of Set 8 | loughrea
# Processing Record 19 of Set 8 | ola
# Processing Record 20 of Set 8 | ithaca
# Processing Record 21 of Set 8 | nicoya
# Processing Record 22 of Set 8 | thakurganj
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | comodoro rivadavia
# Processing Record 25 of Set 8 | tiksi
# Processing Record 26 of Set 8 | sun valley
# Processing Record 27 of Set 8 | collie
# Processing Record 28 of Set 8 | ramhormoz
# Processing Record 29 of Set 8 | chore
# City not found. Skipping...
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 8 | aksu
# Processing Record 32 of Set 8 | lethem
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | mujiayingzi
# Processing Record 35 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 8 | fort nelson
# Processing Record 37 of Set 8 | panguna
# Processing Record 38 of Set 8 | matias romero
# Processing Record 39 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 8 | vanavara
# Processing Record 41 of Set 8 | berlevag
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | ponta do sol
# Processing Record 45 of Set 8 | aguadilla
# Processing Record 46 of Set 8 | buraydah
# Processing Record 47 of Set 8 | pringsewu
# Processing Record 48 of Set 8 | ucluelet
# Processing Record 49 of Set 8 | santa cruz del norte
# Processing Record 50 of Set 8 | jumla
# Processing Record 1 of Set 9 | bambanglipuro
# Processing Record 2 of Set 9 | yaring
# Processing Record 3 of Set 9 | katangli
# Processing Record 4 of Set 9 | dingle
# Processing Record 5 of Set 9 | kovdor
# Processing Record 6 of Set 9 | biloela
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | hualmay
# Processing Record 9 of Set 9 | yacuiba
# Processing Record 10 of Set 9 | durango
# Processing Record 11 of Set 9 | maldonado
# Processing Record 12 of Set 9 | rio gallegos
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | shangrao
# Processing Record 15 of Set 9 | ponnani
# Processing Record 16 of Set 9 | martaban
# Processing Record 17 of Set 9 | sinjar
# Processing Record 18 of Set 9 | madang
# Processing Record 19 of Set 9 | sao felix do xingu
# Processing Record 20 of Set 9 | bazna
# Processing Record 21 of Set 9 | vostok
# Processing Record 22 of Set 9 | port augusta
# Processing Record 23 of Set 9 | urucara
# Processing Record 24 of Set 9 | minggang
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | vao
# Processing Record 27 of Set 9 | la suiza
# Processing Record 28 of Set 9 | paita
# Processing Record 29 of Set 9 | keti bandar
# Processing Record 30 of Set 9 | pangody
# Processing Record 31 of Set 9 | atasu
# Processing Record 32 of Set 9 | kamenka
# Processing Record 33 of Set 9 | peniche
# Processing Record 34 of Set 9 | qasigiannguit
# Processing Record 35 of Set 9 | pilion
# City not found. Skipping...
# Processing Record 36 of Set 9 | kulim
# Processing Record 37 of Set 9 | mar del plata
# Processing Record 38 of Set 9 | manaus
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | uyemskiy
# Processing Record 41 of Set 9 | bull savanna
# Processing Record 42 of Set 9 | stornoway
# Processing Record 43 of Set 9 | buluang
# Processing Record 44 of Set 9 | monkey bay
# Processing Record 45 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 9 | leningradskiy
# Processing Record 47 of Set 9 | alice springs
# Processing Record 48 of Set 9 | dalianwan
# Processing Record 49 of Set 9 | galatista
# Processing Record 50 of Set 9 | constantine
# Processing Record 1 of Set 10 | alibag
# Processing Record 2 of Set 10 | skjervoy
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | sarkand
# Processing Record 5 of Set 10 | kefamenanu
# Processing Record 6 of Set 10 | baghdad
# Processing Record 7 of Set 10 | perbaungan
# Processing Record 8 of Set 10 | orlik
# Processing Record 9 of Set 10 | college
# Processing Record 10 of Set 10 | andilamena
# Processing Record 11 of Set 10 | beringovskiy
# Processing Record 12 of Set 10 | karpathos
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | trat
# Processing Record 15 of Set 10 | pimentel
# Processing Record 16 of Set 10 | bemidji
# Processing Record 17 of Set 10 | kota kinabalu
# Processing Record 18 of Set 10 | san cristobal
# Processing Record 19 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 10 | acarau
# Processing Record 21 of Set 10 | mollendo
# Processing Record 22 of Set 10 | bolgatanga
# Processing Record 23 of Set 10 | rosario
# Processing Record 24 of Set 10 | baykit
# Processing Record 25 of Set 10 | areka
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | dauphin
# Processing Record 28 of Set 10 | mtwara
# Processing Record 29 of Set 10 | pochutla
# Processing Record 30 of Set 10 | palmer
# Processing Record 31 of Set 10 | mount gambier
# Processing Record 32 of Set 10 | evanston
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | booue
# Processing Record 36 of Set 10 | chulman
# Processing Record 37 of Set 10 | rudnyy
# Processing Record 38 of Set 10 | marsa matruh
# Processing Record 39 of Set 10 | dasoguz
# Processing Record 40 of Set 10 | rayachoti
# Processing Record 41 of Set 10 | vilhena
# Processing Record 42 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 10 | aleksandrovskoye
# Processing Record 44 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 10 | matara
# Processing Record 46 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 10 | sojat
# Processing Record 48 of Set 10 | mahibadhoo
# Processing Record 49 of Set 10 | pevek
# Processing Record 50 of Set 10 | bonfim
# Processing Record 1 of Set 11 | amberley
# Processing Record 2 of Set 11 | nouakchott
# Processing Record 3 of Set 11 | bayburt
# Processing Record 4 of Set 11 | san patricio
# Processing Record 5 of Set 11 | grand gaube
# Processing Record 6 of Set 11 | bissau
# Processing Record 7 of Set 11 | moranbah
# Processing Record 8 of Set 11 | monzon
# Processing Record 9 of Set 11 | mbigou
# Processing Record 10 of Set 11 | sibu
# Processing Record 11 of Set 11 | belmonte
# Processing Record 12 of Set 11 | bonnyville
# Processing Record 13 of Set 11 | hasilpur
# Processing Record 14 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 15 of Set 11 | taclobo
# Processing Record 16 of Set 11 | rapid valley
# Processing Record 17 of Set 11 | alice
# Processing Record 18 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | superior
# Processing Record 22 of Set 11 | sorong
# Processing Record 23 of Set 11 | ikole
# City not found. Skipping...
# Processing Record 24 of Set 11 | lagoa
# Processing Record 25 of Set 11 | bom jardim
# Processing Record 26 of Set 11 | san quintin
# Processing Record 27 of Set 11 | batagay-alyta
# Processing Record 28 of Set 11 | lavrentiya
# Processing Record 29 of Set 11 | inuvik
# Processing Record 30 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 31 of Set 11 | byron bay
# Processing Record 32 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 33 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 11 | emerald
# Processing Record 35 of Set 11 | barahona
# Processing Record 36 of Set 11 | moree
# Processing Record 37 of Set 11 | padang
# Processing Record 38 of Set 11 | thinadhoo
# Processing Record 39 of Set 11 | mandalgovi
# Processing Record 40 of Set 11 | evensk
# Processing Record 41 of Set 11 | la asuncion
# Processing Record 42 of Set 11 | batemans bay
# Processing Record 43 of Set 11 | zyryanka
# Processing Record 44 of Set 11 | mariana
# Processing Record 45 of Set 11 | coffs harbour
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | tornio
# Processing Record 48 of Set 11 | nishihara
# Processing Record 49 of Set 11 | dongying
# Processing Record 50 of Set 11 | nuuk
# Processing Record 1 of Set 12 | hearst
# Processing Record 2 of Set 12 | talcahuano
# Processing Record 3 of Set 12 | kitimat
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | ojinaga
# Processing Record 7 of Set 12 | nome
# Processing Record 8 of Set 12 | cuamba
# Processing Record 9 of Set 12 | san jose
# Processing Record 10 of Set 12 | barcelos
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | lhokseumawe
# Processing Record 13 of Set 12 | marrakesh
# Processing Record 14 of Set 12 | vardo
# Processing Record 15 of Set 12 | parbatipur
# Processing Record 16 of Set 12 | mpraeso
# Processing Record 17 of Set 12 | mazagao
# Processing Record 18 of Set 12 | buala
# Processing Record 19 of Set 12 | verkhoyansk
# Processing Record 20 of Set 12 | labuan
# Processing Record 21 of Set 12 | taunggyi
# Processing Record 22 of Set 12 | big rapids
# Processing Record 23 of Set 12 | chama
# Processing Record 24 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 25 of Set 12 | camacari
# Processing Record 26 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 12 | la ronge
# Processing Record 28 of Set 12 | bandar
# Processing Record 29 of Set 12 | gornyye klyuchi
# Processing Record 30 of Set 12 | pokhara
# Processing Record 31 of Set 12 | antofagasta
# Processing Record 32 of Set 12 | lundazi
# Processing Record 33 of Set 12 | suez
# Processing Record 34 of Set 12 | itaituba
# Processing Record 35 of Set 12 | urubicha
# Processing Record 36 of Set 12 | ocean city
# Processing Record 37 of Set 12 | amapa
# Processing Record 38 of Set 12 | yangambi
# Processing Record 39 of Set 12 | cockburn town
# Processing Record 40 of Set 12 | linhai
# Processing Record 41 of Set 12 | todos santos
# Processing Record 42 of Set 12 | batticaloa
# Processing Record 43 of Set 12 | oskarshamn
# Processing Record 44 of Set 12 | douentza
# Processing Record 45 of Set 12 | umm kaddadah
# Processing Record 46 of Set 12 | innisfail
# Processing Record 47 of Set 12 | winslow
# Processing Record 48 of Set 12 | hibbing
# Processing Record 49 of Set 12 | yarada
# Processing Record 50 of Set 12 | hellvik
# Processing Record 1 of Set 13 | esil
# Processing Record 2 of Set 13 | tahe
# Processing Record 3 of Set 13 | katherine
# Processing Record 4 of Set 13 | san juan
# Processing Record 5 of Set 13 | koindu
# Processing Record 6 of Set 13 | new smyrna beach
# Processing Record 7 of Set 13 | tsybli
# Processing Record 8 of Set 13 | bage
# Processing Record 9 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 10 of Set 13 | sao jose da coroa grande
# Processing Record 11 of Set 13 | batagay
# Processing Record 12 of Set 13 | porosozero
# Processing Record 13 of Set 13 | doboj
# Processing Record 14 of Set 13 | iqaluit
# Processing Record 15 of Set 13 | port lincoln
# Processing Record 16 of Set 13 | singapore
# Processing Record 17 of Set 13 | la solana
# Processing Record 18 of Set 13 | pangnirtung
# Processing Record 19 of Set 13 | bereda
# Processing Record 20 of Set 13 | tigzirt
# Processing Record 21 of Set 13 | nelson bay
# Processing Record 22 of Set 13 | belaya gora
# Processing Record 23 of Set 13 | riyadh
# Processing Record 24 of Set 13 | brae
# Processing Record 25 of Set 13 | sosnovo-ozerskoye
# Processing Record 26 of Set 13 | haukipudas
# Processing Record 27 of Set 13 | sfantu gheorghe
# Processing Record 28 of Set 13 | banikoara
# Processing Record 29 of Set 13 | gao
# Processing Record 30 of Set 13 | tochio
# Processing Record 31 of Set 13 | takoradi
# Processing Record 32 of Set 13 | camana
# Processing Record 33 of Set 13 | rustenburg
# Processing Record 34 of Set 13 | cabra
# Processing Record 35 of Set 13 | kalabo
# Processing Record 36 of Set 13 | great yarmouth
# Processing Record 37 of Set 13 | amga
# Processing Record 38 of Set 13 | atikokan
# Processing Record 39 of Set 13 | saint-denis
# Processing Record 40 of Set 13 | homburg
# Processing Record 41 of Set 13 | shiyan
# Processing Record 42 of Set 13 | vage
# Processing Record 43 of Set 13 | sabha
# Processing Record 44 of Set 13 | velluru
# City not found. Skipping...
# Processing Record 45 of Set 13 | los algarrobos
# Processing Record 46 of Set 13 | launceston
# Processing Record 47 of Set 13 | alta floresta
# Processing Record 48 of Set 13 | abha
# Processing Record 49 of Set 13 | salalah
# Processing Record 50 of Set 13 | acapulco
# Processing Record 1 of Set 14 | pangkalanbuun
# Processing Record 2 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 14 | otofuke
# Processing Record 4 of Set 14 | rapallo
# Processing Record 5 of Set 14 | farmington
# Processing Record 6 of Set 14 | yaan
# Processing Record 7 of Set 14 | san jeronimo
# Processing Record 8 of Set 14 | moose factory
# Processing Record 9 of Set 14 | mega
# Processing Record 10 of Set 14 | barao de melgaco
# Processing Record 11 of Set 14 | komsomolskiy
# Processing Record 12 of Set 14 | polson
# Processing Record 13 of Set 14 | matay
# Processing Record 14 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 14 | lahaina
# Processing Record 16 of Set 14 | trairi
# Processing Record 17 of Set 14 | handan
# Processing Record 18 of Set 14 | luceville
# City not found. Skipping...
# Processing Record 19 of Set 14 | enkoping
# Processing Record 20 of Set 14 | isabela
# Processing Record 21 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 22 of Set 14 | badarpur
# Processing Record 23 of Set 14 | chitral
# Processing Record 24 of Set 14 | marienburg
# Processing Record 25 of Set 14 | port macquarie
# Processing Record 26 of Set 14 | pinotepa nacional
# Processing Record 27 of Set 14 | sungaipenuh
# Processing Record 28 of Set 14 | kilindoni
# Processing Record 29 of Set 14 | churapcha
# Processing Record 30 of Set 14 | cao bang
# Processing Record 31 of Set 14 | ust-omchug
# Processing Record 32 of Set 14 | beloha
# Processing Record 33 of Set 14 | bida
# Processing Record 34 of Set 14 | puerto maldonado
# Processing Record 35 of Set 14 | krasnoselkup
# Processing Record 36 of Set 14 | champerico
# Processing Record 37 of Set 14 | cumberland
# Processing Record 38 of Set 14 | mpulungu
# Processing Record 39 of Set 14 | isiro
# Processing Record 40 of Set 14 | severomuysk
# Processing Record 41 of Set 14 | araouane
# Processing Record 42 of Set 14 | kirillov
# Processing Record 43 of Set 14 | nador
# Processing Record 44 of Set 14 | gimli
# Processing Record 45 of Set 14 | raudeberg
# Processing Record 46 of Set 14 | wonthaggi
# Processing Record 47 of Set 14 | mogadishu
# Processing Record 48 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 14 | manggar
# Processing Record 50 of Set 14 | tiarei
# Processing Record 1 of Set 15 | nadym
# Processing Record 2 of Set 15 | arua
# Processing Record 3 of Set 15 | banda aceh
# Processing Record 4 of Set 15 | papara
# Processing Record 5 of Set 15 | birjand
# Processing Record 6 of Set 15 | libreville
# Processing Record 7 of Set 15 | hermon
# Processing Record 8 of Set 15 | sinegorye
# Processing Record 9 of Set 15 | novoilinsk
# Processing Record 10 of Set 15 | muli
# Processing Record 11 of Set 15 | hami
# Processing Record 12 of Set 15 | labrea
# Processing Record 13 of Set 15 | jiuquan
# Processing Record 14 of Set 15 | ternate
# Processing Record 15 of Set 15 | juchipila
# Processing Record 16 of Set 15 | serov
# Processing Record 17 of Set 15 | high rock
# Processing Record 18 of Set 15 | taoudenni
# Processing Record 19 of Set 15 | jingdezhen
# Processing Record 20 of Set 15 | wageningen
# Processing Record 21 of Set 15 | paris
# Processing Record 22 of Set 15 | plettenberg bay
# Processing Record 23 of Set 15 | altamont
# Processing Record 24 of Set 15 | aklavik
# Processing Record 25 of Set 15 | pasighat
# Processing Record 26 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 15 | kyra
# Processing Record 28 of Set 15 | saint-augustin
# Processing Record 29 of Set 15 | liniere
# City not found. Skipping...
# Processing Record 30 of Set 15 | lenzburg
# Processing Record 31 of Set 15 | poum
# Processing Record 32 of Set 15 | altar
# Processing Record 33 of Set 15 | cabedelo
# Processing Record 34 of Set 15 | vanimo
# Processing Record 35 of Set 15 | bukama
# Processing Record 36 of Set 15 | brokopondo
# Processing Record 37 of Set 15 | kampot
# Processing Record 38 of Set 15 | madona
# Processing Record 39 of Set 15 | goderich
# Processing Record 40 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 15 | puruandiro
# Processing Record 42 of Set 15 | catalao
# Processing Record 43 of Set 15 | yershov
# Processing Record 44 of Set 15 | beaverlodge
# Processing Record 45 of Set 15 | aswan
# Processing Record 46 of Set 15 | caravelas
# Processing Record 47 of Set 15 | camocim
# Processing Record 48 of Set 15 | platanos
# Processing Record 49 of Set 15 | ustye
# Processing Record 50 of Set 15 | fort morgan
# Processing Record 1 of Set 16 | soligalich
# Processing Record 2 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 16 | manyana
# Processing Record 4 of Set 16 | bulawayo
# Processing Record 5 of Set 16 | inverbervie
# Processing Record 6 of Set 16 | roebourne
# Processing Record 7 of Set 16 | viljoenskroon
# Processing Record 8 of Set 16 | sechura
# Processing Record 9 of Set 16 | wum
# Processing Record 10 of Set 16 | ararat
# Processing Record 11 of Set 16 | solsvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini -21.2000 -175.2000     75.36        83          73
# 1   Tres Passos -27.4556  -53.9319     69.12        81          43
# 2       Rikitea -23.1203 -134.9692     72.14        77          83
# 3     Cape Town -33.9258   18.4232     56.91        89           8
# 4        Torbay  47.6666  -52.7314     75.88        67          73
# 5    Bredasdorp -34.5322   20.0403     49.96        85          53
# 6        Rawson -43.3002  -65.1023     48.54        49           0
# 7        Avarua -21.2078 -159.7750     77.05        50          75
# 8  Puerto Ayora  -0.7393  -90.3518     72.55        82          56
# 9        Marawi   7.9986  124.2928     67.37        92          74
#
#    Wind Speed Country                 Date Current Description
# 0       22.06      TO  2022-08-02 21:05:34       broken clouds
# 1        4.21      BR  2022-08-02 21:10:25    scattered clouds
# 2       21.72      PF  2022-08-02 21:02:47          light rain
# 3        8.01      ZA  2022-08-02 21:05:28           clear sky
# 4        3.00      CA  2022-08-02 21:10:25       broken clouds
# 5        2.44      ZA  2022-08-02 21:10:26       broken clouds
# 6       10.09      AR  2022-08-02 21:10:26           clear sky
# 7       12.66      CK  2022-08-02 21:04:38       broken clouds
# 8       10.00      EC  2022-08-02 21:02:40       broken clouds
# 9        2.84      PH  2022-08-02 21:10:27       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df=city_data_df[["City","Country", "Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed",
                           "Current Description"]]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0         Vaini      TO  2022-08-02 21:05:34 -21.2000 -175.2000     75.36
# 1   Tres Passos      BR  2022-08-02 21:10:25 -27.4556  -53.9319     69.12
# 2       Rikitea      PF  2022-08-02 21:02:47 -23.1203 -134.9692     72.14
# 3     Cape Town      ZA  2022-08-02 21:05:28 -33.9258   18.4232     56.91
# 4        Torbay      CA  2022-08-02 21:10:25  47.6666  -52.7314     75.88
# 5    Bredasdorp      ZA  2022-08-02 21:10:26 -34.5322   20.0403     49.96
# 6        Rawson      AR  2022-08-02 21:10:26 -43.3002  -65.1023     48.54
# 7        Avarua      CK  2022-08-02 21:04:38 -21.2078 -159.7750     77.05
# 8  Puerto Ayora      EC  2022-08-02 21:02:40  -0.7393  -90.3518     72.55
# 9        Marawi      PH  2022-08-02 21:10:27   7.9986  124.2928     67.37
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        83          73       22.06       broken clouds
# 1        81          43        4.21    scattered clouds
# 2        77          83       21.72          light rain
# 3        89           8        8.01           clear sky
# 4        67          73        3.00       broken clouds
# 5        85          53        2.44       broken clouds
# 6        49           0       10.09           clear sky
# 7        50          75       12.66       broken clouds
# 8        82          56       10.00       broken clouds
# 9        92          74        2.84       broken clouds
